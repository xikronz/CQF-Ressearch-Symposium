# %%
import yfinance as yf
import numpy as np 
import pandas as pd
import requests
import json

# %%
api_url ="https://api.usaspending.gov/api/v2/search/spending_by_award"
headers = {
    'Content-Type': 'application/json'
}

# %%
payload = {
    "subawards": False,
    "limit": 100,
    "page": 1,
    "filters": {
        "time_period": [
            {"start_date": "2007-10-01", "end_date": "2008-09-30"},
            {"start_date": "2008-10-01", "end_date": "2009-09-30"},
            {"start_date": "2009-10-01", "end_date": "2010-09-30"},
            {"start_date": "2010-10-01", "end_date": "2011-09-30"},
            {"start_date": "2011-10-01", "end_date": "2012-09-30"},
            {"start_date": "2012-10-01", "end_date": "2013-09-30"},
            {"start_date": "2013-10-01", "end_date": "2014-09-30"},
            {"start_date": "2014-10-01", "end_date": "2015-09-30"},
            {"start_date": "2015-10-01", "end_date": "2016-09-30"},
            {"start_date": "2016-10-01", "end_date": "2017-09-30"},
            {"start_date": "2017-10-01", "end_date": "2018-09-30"},
            {"start_date": "2018-10-01", "end_date": "2019-09-30"},
            {"start_date": "2019-10-01", "end_date": "2020-09-30"},
            {"start_date": "2020-10-01", "end_date": "2021-09-30"},
            {"start_date": "2021-10-01", "end_date": "2022-09-30"},
            {"start_date": "2022-10-01", "end_date": "2023-09-30"},
            {"start_date": "2023-10-01", "end_date": "2024-09-30"}
        ],
        "award_type_codes": ["A", "B", "C", "D"],
        "naics_codes": [
            "11", "21", "22", "23", "31", "32", "33", "4233", "4235", "4238", "4246", "4247",
            "5111", "5112", "5121", "5122", "5151", "5152", "5161", "5171", "5172", "5173", "5174",
            "5175", "5179", "5181", "5182", "5191", "52", "54"
        ],
        "recipient_type_names": [
            "business", "corporate_entity_not_tax_exempt", "other_than_small_business",
            "subchapter_s_corporation", "partnership_or_limited_liability_partnership", 
            "limited_liability_corporation", "sole_proprietorship", "corporate_entity_tax_exempt", 
            "manufacturer_of_goods"
        ]
    },
    "fields": [
        "Award ID", "Recipient Name", "Award Amount", "Total Outlays", "Description", 
        "Contract Award Type", "def_codes", "COVID-19 Obligations", "COVID-19 Outlays", 
        "Infrastructure Obligations", "Infrastructure Outlays", "Awarding Agency", 
        "Awarding Sub Agency", "Start Date", "End Date", "recipient_id", "prime_award_recipient_id"
    ],
    "order": "desc",
    "sort": "Award Amount"
}

# %%
response = requests.post(api_url, headers=headers, json=payload)
if response.status_code == 200:
    hist_contracts = response.json().get('results', [])
    df = pd.DataFrame(hist_contracts)
    print(df.head())
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
#    internal_id         Award ID                                Recipient Name  \
# 0     24315059    HT940216C0001                HUMANA GOVERNMENT BUSINESS INC
# 1     12178950  DEAC3243AL00036  REGENTS OF THE UNIVERSITY OF CALIFORNIA, THE
# 2     25882618    N0001917C0001                   LOCKHEED MARTIN CORPORATION
# 3     12179201  DEAC5207NA27344     LAWRENCE LIVERMORE NATIONAL SECURITY, LLC
# 4     25881000    N0001902C3002                   LOCKHEED MARTIN CORPORATION
#
#    Award Amount  Total Outlays  \
# 0  4.795233e+10            NaN
# 1  3.527158e+10   2.890800e+07
# 2  3.513584e+10   9.330368e+08
# 3  3.486827e+10   1.102531e+10
# 4  3.413262e+10   2.931389e+07
#
#                                          Description  Contract Award Type  \
# 0                                       IGF::OT::IGF  DEFINITIVE CONTRACT
# 1                          M&O OF LANL BR OF U OF CA  DEFINITIVE CONTRACT
# 2           LRIP LOT 12 ADVANCE ACQUISITION CONTRACT  DEFINITIVE CONTRACT
# 3  TAS::89 0240::TAS THIS PERFORMANCE-BASED MANAG...  DEFINITIVE CONTRACT
# 4  200204!008532!1700!AF600 !NAVAL AIR SYSTEMS CO...  DEFINITIVE CONTRACT
#
#              def_codes  COVID-19 Obligations  COVID-19 Outlays  ...  \
# 0                  [Q]                   NaN               NaN  ...
# 1                  [Q]                   NaN               NaN  ...
# 2               [N, Q]           11234642.22        1741868.78  ...
# 3  [AAA, AAB, N, Q, Z]           12343732.40       12341690.08  ...
# 4               [N, Q]            -624555.70        1530623.99  ...
#
#    Infrastructure Outlays        Awarding Agency  \
# 0                     NaN  Department of Defense
# 1                     NaN   Department of Energy
# 2                     NaN  Department of Defense
# 3             17359702.05   Department of Energy
# 4                     NaN  Department of Defense
#
#                   Awarding Sub Agency  Start Date    End Date  \
# 0               Defense Health Agency  2016-08-01  2025-12-31
# 1                Department of Energy  1978-09-30  2006-05-31
# 2  Defense Contract Management Agency  2017-11-17  2031-03-31
# 3                Department of Energy  2007-05-09  2026-09-30
# 4              Department of the Navy  2001-10-26  2022-12-16
#
#                              recipient_id prime_award_recipient_id  \
# 0  1068e466-707d-6b6f-367f-0255fab79b8c-C                     None
# 1  dfae65bd-32fe-bce0-389c-2867fa9fa04e-C                     None
# 2  6cf5fb1b-4988-d087-5dc1-70939d8fc6c4-C                     None
# 3  6d990129-9566-ff86-e9ae-7c6eeef1df7c-C                     None
# 4  6cf5fb1b-4988-d087-5dc1-70939d8fc6c4-C                     None
#
#   awarding_agency_id            agency_slug  \
# 0               1173  department-of-defense
# 1                930   department-of-energy
# 2               1173  department-of-defense
# 3                930   department-of-energy
# 4               1173  department-of-defense
#
#                          generated_internal_id
# 0    CONT_AWD_HT940216C0001_9700_-NONE-_-NONE-
# 1  CONT_AWD_DEAC3243AL00036_8900_-NONE-_-NONE-
# 2    CONT_AWD_N0001917C0001_9700_-NONE-_-NONE-
# 3  CONT_AWD_DEAC5207NA27344_8900_-NONE-_-NONE-
# 4    CONT_AWD_N0001902C3002_9700_-NONE-_-NONE-
#
# [5 rows x 21 columns]
